# %% [markdown]
# # Time-series analysis

# %%
import pandas as pd

# %%
apm_table = pd.read_csv('./1808-12.csv', names=['server_id', 'ds', 'y'])

# %%
time_usage_pair_for_each_server = {}

# %%
server_ids = set(apm_table["server_id"])

# %%
for server_id in server_ids:
    apm_data = apm_table[apm_table['server_id'] == server_id][['ds', 'y']]
    apm_data = apm_data.sort_values('ds').reset_index(drop=True)
    time_usage_pair_for_each_server[server_id] = apm_data

# %%
import fbprophet

# %%
apm_prophet = fbprophet.Prophet(changepoint_prior_scale=0.05)

# %%
target_agent = time_usage_pair_for_each_server[288][-60*24*7:]

# %%
apm_prophet.fit(target_agent)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# /Users/sewookoh/anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
apm_forecast = apm_prophet.make_future_dataframe(periods=60, freq='min')

apm_forecast = apm_prophet.predict(apm_forecast)

# %%
import matplotlib.pyplot as plt
apm_prophet.plot(apm_forecast, xlabel="Date", ylabel="CPU Usage")
plt.title('CPU Usage of server 514')
# Out:
# Text(0.5,1,'CPU Usage of server 514')

# %%
selected_df = apm_forecast[-60:]

selected_df.plot('ds', ['yhat_lower', 'yhat_upper', 'yhat'])
plt.ylabel('CPU Usage')
plt.xlabel('Time (min)')
# Out:
# Text(0.5,0,'Time (min)')

# %%
selected_df[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#                        ds      yhat  yhat_lower  yhat_upper
# 10080 2018-12-24 15:33:51  1.301248   -0.913538    3.387110
# 10081 2018-12-24 15:34:51  1.301399   -0.838854    3.454065
# 10082 2018-12-24 15:35:51  1.301541   -0.780932    3.565038
# 10083 2018-12-24 15:36:51  1.301674   -0.711141    3.526829
# 10084 2018-12-24 15:37:51  1.301797   -0.775404    3.386459
# 10085 2018-12-24 15:38:51  1.301910   -0.844738    3.406282
# 10086 2018-12-24 15:39:51  1.302014   -0.777614    3.504370
# 10087 2018-12-24 15:40:51  1.302108   -0.812187    3.497177
# 10088 2018-12-24 15:41:51  1.302192   -0.839399    3.405921
# 10089 2018-12-24 15:42:51  1.302267   -0.758970    3.432531
# 10090 2018-12-24 15:43:51  1.302331   -0.917662    3.363359
# 10091 2018-12-24 15:44:51  1.302385   -0.769940    3.448217
# 10092 2018-12-24 15:45:51  1.302430   -0.790399    3.394107
# 10093 2018-12-24 15:46:51  1.302464   -1.100333    3.403284
# 10094 2018-12-24 15:47:51  1.302488   -0.921712    3.295719
# 10095 2018-12-24 15:48:51  1.302502   -0.688747    3.517121
# 10096 2018-12-24 15:49:51  1.302506   -0.827466    3.438944
# 10097 2018-12-24 15:50:51  1.302500   -0.696252    3.525609
# 10098 2018-12-24 15:51:51  1.302484   -0.926968    3.386349
# 10099 2018-12-24 15:52:51  1.302457   -0.833687    3.470999
# 10100 2018-12-24 15:53:51  1.302420   -0.671236    3.431792
# 10101 2018-12-24 15:54:51  1.302373   -0.858985    3.529494
# 10102 2018-12-24 15:55:51  1.302316   -0.722526    3.373964
# 10103 2018-12-24 15:56:51  1.302248   -0.800101    3.356453
